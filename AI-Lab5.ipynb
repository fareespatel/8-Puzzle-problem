# %%
sequence=[349528396,
352181956,
352170292,
351855364,
352268140,
352268356,
352268388,
352266932,
349613372,
345361844,
39251828,
340165532,
340480460,
340509620,
339978908,
305966684,
38120420,
296046452,
296308892,
296335100,
296335116,
296334388,
292088692,
262327996,
32745484,
247683844,
247893796]

# %%
def Puzzle_Matrix(orig_num):
    puzzle=list()
    for i in range(9):
        digit= orig_num%9
        orig_num=(orig_num-digit)/9
        puzzle.append(digit)
    return(puzzle)

# %%
for i in sequence:
    print("Score(Number) :",i)
    print("Problem instance: ")
    for row in np.array(Puzzle_Matrix(i),dtype=np.int).reshape(3,3):
        print(" ".join(map(str,row)))
    print("\n")
# Out:
# Score(Number) : 349528396
# Problem instance:
# 4 3 7
# 5 2 6
# 0 1 8
#
#
# Score(Number) : 352181956
# Problem instance:
# 4 3 7
# 0 2 6
# 5 1 8
#
#
# Score(Number) : 352170292
# Problem instance:
# 4 3 7
# 2 0 6
# 5 1 8
#
#
# Score(Number) : 351855364
# Problem instance:
# 4 3 7
# 2 6 0
# 5 1 8
#
#
# Score(Number) : 352268140
# Problem instance:
# 4 3 0
# 2 6 7
# 5 1 8
#
#
# Score(Number) : 352268356
# Problem instance:
# 4 0 3
# 2 6 7
# 5 1 8
#
#
# Score(Number) : 352268388
# Problem instance:
# 0 4 3
# 2 6 7
# 5 1 8
#
#
# Score(Number) : 352266932
# Problem instance:
# 2 4 3
# 0 6 7
# 5 1 8
#
#
# Score(Number) : 349613372
# Problem instance:
# 2 4 3
# 5 6 7
# 0 1 8
#
#
# Score(Number) : 345361844
# Problem instance:
# 2 4 3
# 5 6 7
# 1 0 8
#
#
# Score(Number) : 39251828
# Problem instance:
# 2 4 3
# 5 6 7
# 1 8 0
#
#
# Score(Number) : 340165532
# Problem instance:
# 2 4 3
# 5 6 0
# 1 8 7
#
#
# Score(Number) : 340480460
# Problem instance:
# 2 4 3
# 5 0 6
# 1 8 7
#
#
# ...
